# %% [markdown]
# ### stack implementation without using library

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if len(self.stack)==0:
            print("The stack is empty, no more element to pop")
            return None
            
        return self.stack.pop()
        
    def print_stack(self):
        print(self.stack)

    def empty_stack(self):
        return len(self.stack)==0


stack1 = Stack()

stack1.push(10)
stack1.push(0)
stack1.push(25)
stack1.push(30)

stack1.print_stack()

stack1.pop()
stack1.pop()
stack1.print_stack()


stack2=Stack()

stack2.push(30)
stack2.push(10)

stack2.print_stack()

stack2.pop()
stack2.pop()
stack2.pop()
stack2.print_stack()
# Out:
# [10, 0, 25, 30]
# [10, 0]
# [30, 10]
# The stack is empty, no more element to pop
# []

# %% [markdown]
# ### Stack implementation using library

# %%
l_stack=[]

l_stack.append(10)
l_stack.append(20)
l_stack.append(30)
l_stack.append(40)

print("Stack after pushing and before poping",l_stack)

for i in range(len(l_stack)):
    rmv=l_stack.pop()
    print(f"Removed element from stack is",rmv)
    print(l_stack)
    if len(l_stack)==0:
        print("The stack is empty , no more emelemt can be popped")
# Out:
# Stack after pushing and before poping [10, 20, 30, 40]
# Removed element from stack is 40
# [10, 20, 30]
# Removed element from stack is 30
# [10, 20]
# Removed element from stack is 20
# [10]
# Removed element from stack is 10
# []
# The stack is empty , no more emelemt can be popped

# %% [markdown]
# ###  queue implementation without using library

# %%
class Queue:
    def __init__(self):
        self.queue=[]
    def enqueue(self,item):
        return self.queue.append(item)
    
    def dequeue(self):
        if len(self.queue)==0:
            print("the queue is empty,no more element to dequeue")
            return None
        
        return self.queue.pop(0)
    
    def print_queue(self):
        print(self.queue)

    def empty_queue(self):
        return len(self.queue)==0

queue1=Queue()
queue1.enqueue(10)
queue1.enqueue(20)
queue1.enqueue(30)
queue1.print_queue()

queue1.dequeue()
queue1.dequeue()
print("The remaining element in the queue is:")
queue1.print_queue()
queue1.dequeue()
queue1.dequeue()
queue1.print_queue()
# Out:
# [10, 20, 30]
# The remaining element in the queue is:
# [30]
# the queue is empty,no more element to dequeue
# []

# %% [markdown]
# ### implementation using library

# %%
from collections import deque

q=deque()

q.append(10)
q.append(20)
q.append(30)

print("The elements in the queue are",list(q))

for i in range(1,len(q)+1):
    item=q.popleft()
    print("The element to be dequeued is",item)
    print("The elements in the queue are",(q))

    if len(q)==0:
        print("Np more element to to be dequeue")
# Out:
# The elements in the queue are [10, 20, 30]
# The element to be dequeued is 10
# The elements in the queue are deque([20, 30])
# The element to be dequeued is 20
# The elements in the queue are deque([30])
# The element to be dequeued is 30
# The elements in the queue are deque([])
# Np more element to to be dequeue

# %% [markdown]
# ### implementation of linked list without using library

# %%
class Node:
    def __init__(self, data):
        self.data=data
        self.next=None

class linked_l:
    def __init__(self):
        self.head=None

    def create(self):
        node1=Node(10)
        self.head=node1

        node2=Node(20)
        node1.next=node2

        node3=Node(30)
        node2.next=node3

        node4=Node(40)
        node3.next=node4

ll1=linked_l()

ll1.create()

current_node=ll1.head

while current_node:
    print(current_node.data,end='-->')
    current_node=current_node.next

print("None")
# Out:
# 10-->20-->30-->40-->None

# %% [markdown]
# ### using libraries

# %%
from collections import deque

ll=deque()

ll.append(10)
ll.append(20)
ll.append(30)
ll.append(40)

print("Linked list:",list(ll))

print("popleft(element)->",ll.popleft())  
print("pop(element) ->",  ll.pop())           
print("Now list :", list(ll))

ll.append(50)
print("After adding to right :",list(ll))

ll.appendleft(60)
print("After adding to left :",list(ll))
# Out:
# Linked list: [10, 20, 30, 40]
# popleft(element)-> 10
# pop(element) -> 40
# Now list : [20, 30]
# After adding to right : [20, 30, 50]
# After adding to left : [60, 20, 30, 50]

# %%
from heapq import heappush, heappop, heapify

heap=[]
heappush(heap,-10)
heappush(heap,20)
heappush(heap,30)
heappush(heap,3)


print(heap)

print("Minimum value:", heappop(heap))
print(heap)

print("Minimum value:", heap[0])
print(heap)

arr=[1,5,3,2]
heapify(arr)
print(arr)
# Out:
# [-10, 3, 30, 20]
# Minimum value: -10
# [3, 20, 30]
# Minimum value: 3
# [3, 20, 30]
# [1, 2, 3, 5]

# %%
import networkx as nx

tree=nx.DiGraph()

tree.add_edge(100, 99)   
tree.add_edge(100, 101) 

print(tree.nodes)
print(tree.edges)
# Out:
# [100, 99, 101]
# [(100, 99), (100, 101)]

# %%
class Node:
    def __init__(self,data):
        self.left=None
        self.right=None
        self.data=data

    def show(self):
        if self.left:
            self.left.show()

        if self.right:
            self.right.show()
            
        print(self.data)

root=Node(100)
r_left=Node(99)
r_right=Node(101)

root.left=r_left
root.right=r_right
root.show()
# Out:
# 99
# 101
# 100

# %% [markdown]
# ### implementation of graph using library

# %%
import networkx as nx

graph=nx.Graph()

graph.add_edge(10,20)
graph.add_edge(30,40)
graph.add_edge(50,60)

print("Nodes:",graph.nodes())
print("Nodes:",graph.edges())
# Out:
# Nodes: [10, 20, 30, 40, 50, 60]
# Nodes: [(10, 20), (30, 40), (50, 60)]
