# %% [markdown]
# ## Mini Assignment 1

# %% [markdown]
# #### 1. Print your full name

# %%
print("Aayush Neupane")
# Out:
# Aayush Neupane

# %% [markdown]
# ####  2. Print your fav quote

# %%
print("Go with the flow but dont be a dead fish")
# Out:
# Go with the flow but dont be a dead fish

# %% [markdown]
# #### 3. Print a sentence in a multiple line using \n

# %%
print("This is example of \n of breaking sentence")
# Out:
# This is example of
#  of breaking sentence

# %% [markdown]
# ### Mini Assignment 2

# %%
name="Aayush Neupane"
age=20 
country="Nepal"

# %%
print(f" My name is {name} and my age is {age} \n I live in country {country}")
# Out:
#  My name is Aayush Neupane and my age is 20
#  I live in country Nepal

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(country))
# Out:
# <class 'str'>

# %% [markdown]
# ### Assignment to be done in copy.  Explain different  operator and example of each
#
# airthmentic, comparison, logical, assignment , memebership, identity
#
# like 3<=4
#
# ### Describe the process of  inoput and output in python

# %%
a=5
print("hello",a,"goodmorning")
# Out:
# hello 5 goodmorning

# %%
list1=[2,3,4,5]
list3=list1
list2=[2,3,4,5]
print(list3 is list1)
print(list1 is list2)
# Out:
# True
# False

# %% [markdown]
# ## Mini assignment 3

# %%
a=float(input("Enter the number:"))
b=int(input("Enter the number:"))
print("Addition",a+b)
print("Subtraction",a-b)
print("Multiplication",a*b)
# Out:
# Enter the number: 3.4
# Enter the number: 3
# Addition 6.4
# Subtraction 0.3999999999999999
# Multiplication 10.2

# %%
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))

if a%b==0:
    print("The number is perfectly divisble")
else:
    print("Not")
# Out:
# Enter the number: 4
# Enter the number: 2
# The number is divisble

# %%
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))

if a%2==0 and b%2==0:
    print("Both number is even")
elif a%2!=0 and b%2==0:
    print("Number 1 is Odd and Number 2 is even")
elif a%2==0 and b%2!=0:
    print("Number 1 is even and 2 is odd")
else:
    print("Both numbers are odd")
# Out:
# Enter the number: 2
# Enter the number: 3
# Number 1 is even and 2 is odd

# %% [markdown]
# ## miniassigment 5

# %%
#checking the number is positive , gnegative or zero

a=int(input("Enter the number:"))

if a<0:
    print("Negative")
elif a>0:
    print("Positive")
else:
    print("Zero")
# Out:
# Enter the number: 2
# Positive

# %%
#checking the grades after marks

a=int(input("Enter the amrks"))

if a>=90:
    print("A")
elif a<=80 and a>=75:
    print("B")
elif a<=75 and a>=65:
    print("C")
else:
    print("Fail")
# Out:
# Enter the amrks 70
# C

# %%
#checkin gif the number is odd or even

a=int(input("Enter the number"))

if a%2==0:
      print("The number is even")

else:
      print("The number is odd")
# Out:
# Enter the number 4
# The number is even

# %% [markdown]
# ### Python Switch and nested condition

# %%
day = input("Day:")

match day:
    case "Sunday":
        print(f"welcome {day}")
    case "Monday":
        print(f"welcome {day}")
    case _:
        print("Enter valid day")
# Out:
# Day: 1232
# Enter valid day

# %%
age=10
if (age)>=19:
    print("welcome")
else:
    print("False")
# Out:
# False

# %%
age=18
print(type(age))
# print(len(age))
# Out:
# <class 'int'>

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
name="aayush"
print(len(name))
# Out:
# 6

# %%
age=[1,2,3,4]
print(max(age))
# Out:
# 4

# %%
class1={
    'name',
    1,
    9.8,
    'list1=[1,2,3]'
    
}
for i in class1:
    print(f"Data type: {type(i)}")
# Out:
# Data type: <class 'int'>
# Data type: <class 'str'>
# Data type: <class 'str'>
# Data type: <class 'float'>

# %% [markdown]
# ### Assignment

# %%
#take 3 number and ask for the largest number 

num1=int(input())
num2=int(input())
num3=int(input())

def large(num1,num2,num3):
    if num1>num2 and num1>num3:
        print(f"{num1} is the largest")
    elif num2>num3:
        print(f"{num2} is the largest")
    else:
        print(f"{num3} is the largest")
    

large(num1,num2,num3)
# Out:
#  5
#  5
#  6
# 6 is the largest

# %%
#multiplication of number and highlighting the multiple of 5 

n=int(input("Enter an integer:\n"))

def mul(n):
    for i in range(1,11):
        r=i*n
        print(f"{n}*{i}={r}")

        if r%5==0:
            print("This result is multiple of 5")
        
mul(n)
# Out:
# Enter an integer:
#  3
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# This result is multiple of 5
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# 3*10=30
# This result is multiple of 5

# %%
# rolling dice 10 timnes and couting 6 

import random as r

def count_dice():
