# %%
my_list=[2,1,2,4,3]
my_list.append(5)
print(my_list)
#insert ko suru ko parameter gives indexing ani second ko le value 
my_list.insert(3,10)
print(my_list)

#you can;t remove what is not unside the lsit 
my_list.remove(3)
print(my_list)

popped_element=my_list.pop()
print(popped_element)
print(my_list)
my_list.sort()
new_list=my_list
print(new_list)

sort_el=['a','v','b','c','b']
# sort_el.sort()
# sort_el

#list may contain different data types but we cannot sort the list that has different data type
# Out:
# [2, 1, 2, 4, 3, 5]
# [2, 1, 2, 10, 4, 3, 5]
# [2, 1, 2, 10, 4, 5]
# 5
# [2, 1, 2, 10, 4]
# [1, 2, 2, 4, 10]

# %%
a = [1,4,3,23, 0]
b = a.sort()
a, b
# Out:
# ([0, 1, 3, 4, 23], None)

# %% [markdown]
# ### list slicing

# %%
a=[1,2,3,4,5,6,7,8,9]
print(a[1:4])
print(a[:3:3])
print(a[-2:])


b=['aa',1,4.5,7,9,4,3]
print(b[::-1])
print(b[2:-2:2])
# Out:
# [2, 3, 4]
# [1]
# [8, 9]
# [3, 4, 9, 7, 4.5, 1, 'aa']
# [4.5, 9]

# %% [markdown]
# ## TUPLE

# %%
#why tuple is faster than lsit 

import time as t 

start = t.time()
for _ in range(5_000_000):
    a=[1,2,3,4]
end=t.time()
print("list exec time:",end-start)

start = t.time()
for _ in range(5_000_000):
    a=(1,2,3,4)
end=t.time()
print("Tuple exec time:",end-start)
# Out:
# list exec time: 0.9165177345275879
# Tuple exec time: 0.4739499092102051

# %%
import sys

a=[1,2,3,4,5]
b=(1,2,3,4,5)

print(sys.getsizeof(a))
print(sys.getsizeof(b))
# Out:
# 104
# 80

# %% [markdown]
# ## set

# %%
A={1,2,3}
B={3,4,5}
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
print(A.symmetric_difference(B))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}

# %%
a=[5,6,7,8,9,10]
print(a[2::-2])
print(a[-2::2])
# Out:
# [7, 5]
# [9]

# %%
student={
    "name":"Alexx",
    "age":21,
    "grades":"A",
    "s":{
        "class":"ignite"
    
    }
}
print(student["name"])
print(student["age"])

p=student.pop("age")
print(p)

g=student.get("grades")
print(g)


# print(student.keys())
# print(student.values())
# print(student.items())
# print(student.get("grades"))
# print(student.pop("age"))
# Out:
# Alexx
# 21
# 21
# A

# %%
from array import array

arr=array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
from collections import Counter

c=Counter("banana")
print(c)

from collections import defaultdict
d=defaultdict(int)
d["a"]+=1
print(d)

from collections import namedtuple

Point=namedtuple("Point","x y")
p=Point(10,20)
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})
# defaultdict(<class 'int'>, {'a': 1})

# %% [markdown]
# ## questions
#
# 1)Store student names in a list and sort them
# 2)Count frequency of characters using counter

# %%
n=[
    "Aayush Neupane", "Aastha Acharya","Smriti Neupane","Jiban Neupane"
]
n.sort()
print(n)
# Out:
# ['Aastha Acharya', 'Aayush Neupane', 'Jiban Neupane', 'Smriti Neupane']

# %%
from collections import Counter

word=input("Enter the words:")
c=Counter(word)
print(f"The total count of word is {c}")
# Out:
# Enter the words: aayush
# The total count of word is Counter({'a': 2, 'y': 1, 'u': 1, 's': 1, 'h': 1})
