# %% [markdown]
# ### Class Assignment

# %%
#take 3 number and ask for the largest number 

num1=int(input("Enter the 1 integer:"))
num2=int(input("Enter the 2 integer:"))
num3=int(input("Enter the 3 integer:"))

def large(num1,num2,num3):
    if num1>num2 and num1>num3:
        print(f"{num1} is the largest")
    elif num2>num3:
        print(f"{num2} is the largest")
    else:
        print(f"{num3} is the largest")
    

large(num1,num2,num3)

def largest(numbers):
    largest=numbers[0]
    for num in numbers:
        if num > largest:
            largest = num
    print(f"the largest is{largest}")
        
a=int(input("Enter a"))
b=int(input("Enter b"))
c=int(input("Enter c"))
d=int(input("Enter d"))
e=int(input("Enter e"))
numbers=[a,b,c,d,e]
largest(numbers)
# Out:
# Enter the 1 integer: 5
# Enter the 2 integer: 6
# Enter the 3 integer: 6
# 6 is the largest
# Enter a 8
# Enter b 9
# Enter c 8
# Enter d 5
# Enter e 2.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 29
#      27 c=int(input("Enter c"))
#      28 d=int(input("Enter d"))
# ---> 29 e=int(input("Enter e"))
#      30 numbers=[a,b,c,d,e]
#      31 largest(numbers)
#
# ValueError: invalid literal for int() with base 10: '2.0'

# %%
#multiplication of number and highlighting the multiple of 5 

n=int(input("Enter an integer:\n"))

def mul(n):
    for i in range(1,11):
        r=i*n
        if r%5==0:
            print(f"\033[1m{n}*{i}={r}\033[0m")
        else:
            print(f"{n}*{i}={r}")

       
        
mul(n)
# Out:
# Enter an integer:
#  2
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20

# %%
# rolling dice 10 times using random.randint() and coutning number of 6

import random as r

def count_d():
    count=0
    for i in range(10):
        roll=r.randint(1,6)
        print(f"Number in dice while that was rolled {i+1} time:{roll}")
        if roll==6:
            count+=1

    return count


res=count_d()
print(f"There were total {res} occurance of 6")
# Out:
# Number in dice while that was rolled 1 time:4
# Number in dice while that was rolled 2 time:2
# Number in dice while that was rolled 3 time:1
# Number in dice while that was rolled 4 time:3
# Number in dice while that was rolled 5 time:2
# Number in dice while that was rolled 6 time:6
# Number in dice while that was rolled 7 time:3
# Number in dice while that was rolled 8 time:3
# Number in dice while that was rolled 9 time:4
# Number in dice while that was rolled 10 time:1
# There were total 1 occurance of 6

# %%
# ask the user input a word and count vowels and consontant using a function 

word=input("Enter a word:").lower()
vowels='aeiou'

def count_(word):
    vowel=0 
    consonant=0
    for i in word:
        if i in vowels:
            vowel+=1
        else:
            consonant+=1
        
    print(f"The total number of vowel in the word is {vowel} and cosntant is {consonant}")

count_(word)
# Out:
# Enter a word: aayush
# The total number of vowel in the word is 3 and cosntant is 3

# %%
def grade(avg):
    if avg >=90:
        return "A+"
    elif avg >=80:
        return "A"
    elif avg >=70:
        return "B"
    elif avg >=60:
        return "C"
    elif avg >=50:
        return "D"
    else:
        return "F"

names=[]
all_marks=[]

n=int(input("Enter the number of students"))
for i in range(n):
    name=input(f"Enter name of student {i+1}:")
    marks = list(map(int, input("Enter marks separated by space:").split()))

    names.append(name)
    all_marks.append(marks)

print("\nRESULTS")

for i in range(n):
    total=sum(all_marks[i])
    avg=total/len(all_marks[i])
    grade=grade(avg)

    print(f"\nStudent:{names[i]}")
    print(f"Marks:{all_marks[i]}")
    print(f"Total:{total}")
    print(f"Average:{avg:.2f}")
    print(f"Grade:{grade}")
# Out:
# Enter the number of students 1
# Enter name of student 1: aayish
# Enter marks separated by space: 10 20 40
# RESULTS
#
# Student:aayish
# Marks:[10, 20, 40]
# Total:70
# Average:23.33
# Grade:F
